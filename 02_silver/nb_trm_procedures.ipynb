# %%
df = spark.read.table('medical_catalog.bronze.procedures')
display(df.limit(10))

# %%
# Convert columns to snakecase
for col in df.columns:
    new_col = col.lower().replace(' ', '_')
    if new_col != col:
        df = df.withColumnRenamed(col, new_col)
display(df.limit(10))

# %%
# Handling nulls
from pyspark.sql.functions import when, col

df = df.withColumn("reasoncode", when(col("reasoncode").isNull(),0.00 ).otherwise(col("reasoncode")))
df = df.withColumn("reasondescription", when(col("reasondescription").isNull(), "Unknown").otherwise(col("reasondescription")))
display(df.limit(10))

# %%
from pyspark.sql.functions import rand

df = df.withColumn("procedure_id", (rand() * 1e12).cast("long"))
display(df.limit(10))

# %%
df.write.mode("overwrite").saveAsTable("medical_catalog.silver.procedures")
