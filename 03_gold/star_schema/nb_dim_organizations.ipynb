-- %% [markdown]
-- ### Organization (Dimension Table)

-- %%
CREATE OR REPLACE TABLE medical_catalog.gold.dim_organization AS
SELECT DISTINCT
    id as organization_id,
    name as organization_name,
    city,
    state
FROM medical_catalog.silver.organizations;
