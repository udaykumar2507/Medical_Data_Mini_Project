-- %%
CREATE OR REPLACE TABLE medical_catalog.gold.dim_procedure AS
SELECT DISTINCT
    procedure_id,
    encounter_id,
    base_cost,
    code as procedure_code
FROM medical_catalog.silver.procedures;
