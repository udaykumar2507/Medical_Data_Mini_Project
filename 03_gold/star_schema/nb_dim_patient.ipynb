-- %% [markdown]
-- ### Patient (Dimension Table)

-- %%
CREATE OR REPLACE TABLE medical_catalog.gold.dim_patient AS
SELECT DISTINCT
    id as patient_id,
    gender,
    birthdate,
    ethnicity
FROM medical_catalog.silver.patients;
