# %% [markdown]
# ### PIPELINE FOR SILVER

# %%
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/02_silver/nb_trm_encounters",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/02_silver/nb_trm_organizations",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/02_silver/nb_trm_patients",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/02_silver/nb_trm_payers",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/02_silver/nb_trm_procedures",3600)
