# %%
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/star_schema/nb_dim_calender",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/star_schema/nb_dim_organizations",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/star_schema/nb_dim_patient",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/star_schema/nb_dim_payers",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/star_schema/nb_dim_procedures",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/star_schema/nb_fact_table",3600)
dbutils.notebook.run("/Workspace/Users/uk25072004@gmail.com/Medical_Data_DE_Mini_Project/03_gold/KPI/final_kpi",3600)
